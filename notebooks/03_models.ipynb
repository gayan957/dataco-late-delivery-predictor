# %% [markdown]
# # 03 – Model Comparison
#
# **Owner: M1 / M4 (collaborative)**
#
# Compare all trained models side-by-side using the metrics logged to
# `results/experiments.csv`.
#
# Models covered:
# - Logistic Regression (`src/train_logreg.py`)
# - Decision Tree      (`src/train_tree_knn.py --model tree`)
# - K-Nearest Neighbours (`src/train_tree_knn.py --model knn`)
# - Random Forest      (`src/train_rf.py`)
# - **XGBoost**        (`src/train_xgb.py`) ← M3, best expected model
#
# **Prerequisites**: all `make train-*` commands have been run.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.config import RESULTS_DIR

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 1. Load experiment log
# TODO M4

# %%
# TODO M4: load results/experiments.csv
# df = pd.read_csv(RESULTS_DIR / 'experiments.csv')
# df

# %% [markdown]
# ## 2. Metric bar chart
# TODO M4

# %%
# TODO M4: grouped bar chart of accuracy, f1, roc_auc per model

# %% [markdown]
# ## 3. ROC curves
# TODO M4

# %%
# TODO M4: load each model .pkl, compute ROC, overlay on one plot

# %% [markdown]
# ## 4. Precision-Recall curves
# TODO M4

# %%
# TODO M4: PR curves for each model

# %% [markdown]
# ## 5. Confusion matrices
# TODO M4

# %%
# TODO M4: 2×3 grid of confusion matrices

# %% [markdown]
# ## 6. Conclusion
#
# TODO M4: write up which model wins and why, referencing metrics above.
