# %% [markdown]
# # 01 – Exploratory Data Analysis
#
# **Owner: M2**
#
# Analyse the raw DataCo Supply Chain dataset before any cleaning or
# feature engineering.  This notebook feeds directly into `src/features.py`
# — findings here motivate which engineered columns to add.
#
# ---
# **Dataset facts (do not re-derive)**
# - `data/raw/DataCoSupplyChainDataset.csv` — 180,519 rows × 53 cols, LATIN-1
# - Target: `Late_delivery_risk` (1 = late, 54.8 %)
# - Leakage cols: see `src.config.LEAKAGE_COLS`
# - Drop cols: see `src.config.DROP_COLS`
# - Exclude: `Order Status` ∈ `{'CANCELED', 'SUSPECTED_FRAUD'}` (7,754 rows)

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.config import DATA_RAW, LEAKAGE_COLS, DROP_COLS, CANCELLED_STATUSES, TARGET

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %%
# TODO M2: Load raw CSV
# df = pd.read_csv(DATA_RAW, encoding='latin-1')
# print(df.shape)
# df.head()

# %% [markdown]
# ## 1. Dataset shape & dtypes
# TODO M2

# %%
# TODO M2: df.dtypes, df.info(), null counts

# %% [markdown]
# ## 2. Target distribution
# TODO M2

# %%
# TODO M2: plot target class balance (should be ~54.8% late)

# %% [markdown]
# ## 3. Null / missing values
# TODO M2

# %%
# TODO M2: visualise null fractions (Order Zipcode ~86%, Product Description 100%)

# %% [markdown]
# ## 4. Categorical cardinalities
# TODO M2

# %%
# TODO M2: nunique() for each categorical; confirm Order City~3597, etc.

# %% [markdown]
# ## 5. Numeric distributions & outliers
# TODO M2

# %%
# TODO M2: histograms / box-plots for numeric cols; note any extreme skew

# %% [markdown]
# ## 6. Correlation heatmap (numeric vs target)
# TODO M2

# %%
# TODO M2: correlation matrix; identify collinear pairs for M3's select_features()

# %% [markdown]
# ## 7. Date feature exploration
# TODO M2

# %%
# TODO M2: parse 'order date (DateOrders)'; plot late-rate by month, weekday, quarter

# %% [markdown]
# ## 8. Geo exploration
# TODO M2

# %%
# TODO M2: late-rate by Order Region / Market; scatter Lat vs Lon coloured by target

# %% [markdown]
# ## 9. Key findings → features.py
#
# TODO M2: summarise which engineered features are worth adding:
# - date features: `order_month`, `order_dayofweek`, `order_quarter`, `is_weekend`
# - geo features: `dist_to_equator`, `lat_bin`, `lon_bin`
# - order features: `items_per_order`, `discount_to_price`, `effective_price`
